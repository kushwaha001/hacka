# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Train.csv')
df
# Out:
#          V1     V2     V3  V4       V5      V6    V7  V8     V9  V10  ...  \
# 0       0.0    1.0  243.0  29   4528.0   138.0   3.0  29  201.0  0.0  ...
# 1       0.0   20.0    8.0  14   4183.0   183.0   4.0  26  156.0  0.0  ...
# 2      14.0    2.0    2.0   9   1113.0    15.0  37.0  31   78.0  1.0  ...
# 3       0.0  175.0   17.0  16   4250.0    68.0   8.0  30  152.0  0.0  ...
# 4       2.0   -1.0    1.0   3      0.0     0.0   2.0   5    6.0  1.0  ...
# ...     ...    ...    ...  ..      ...     ...   ...  ..    ...  ...  ...
# 40771   0.0    0.0    4.0   5  41928.0  1836.0   1.0  11  307.0  0.0  ...
# 40772   1.0   90.0    6.0   5   1376.0     5.0  71.0   5  155.0  1.0  ...
# 40773   0.0    2.0   10.0  35   1424.0    46.0  17.0  42  190.0  0.0  ...
# 40774   1.0   22.0    1.0   1      0.0     0.0   1.0   1    8.0  1.0  ...
# 40775   0.0    7.0   27.0   3   1946.0    74.0   2.0   5    7.0  0.0  ...
#
#        V45  V47   V50  V51  V52   V59  V63  V72  V75  class
# ...

# %%
X=df.drop(['class'],axis=1)
y=df['class']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
df.shape
# Out:
# (40776, 32)

# %%
X_std = MinMaxScaler().fit_transform(X)
X_std
# Out:
# array([[0.00000000e+00, 2.44379277e-04, 7.42143359e-03, ...,
#         7.69230769e-02, 1.70940171e-02, 0.00000000e+00],
#        [0.00000000e+00, 1.79211470e-03, 2.44327032e-04, ...,
#         6.92307692e-01, 5.12820513e-02, 0.00000000e+00],
#        [1.71568627e-02, 3.25839036e-04, 6.10817579e-05, ...,
#         6.92307692e-01, 1.70940171e-02, 7.35294118e-03],
#        ...,
#        [0.00000000e+00, 3.25839036e-04, 3.05408790e-04, ...,
#         4.61538462e-01, 1.45299145e-01, 7.35294118e-03],
#        [1.22549020e-03, 1.95503421e-03, 3.05408790e-05, ...,
#         4.61538462e-01, 2.56410256e-02, 1.47058824e-02],
#        [0.00000000e+00, 7.33137830e-04, 8.24603732e-04, ...,
#         6.15384615e-01, 3.41880342e-02, 4.41176471e-02]])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=660)

# %%
log_reg_l1 = LogisticRegression(penalty='l1', solver='liblinear', C=.08)
log_reg_l1.fit(X_train, y_train)

# For L2 regularization
log_reg_l2 = LogisticRegression(penalty='l2', solver='liblinear', C=.08)
log_reg_l2.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 log_reg_l1 = LogisticRegression(penalty='l1', solver='liblinear', C=.08)
# ----> 2 log_reg_l1.fit(X_train, y_train)
#       4 # For L2 regularization
#       5 log_reg_l2 = LogisticRegression(penalty='l2', solver='liblinear', C=.08)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
X_train, X_val, y_train, y_val = train_test_split(X_std, y, test_size = 0.29)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=660)

# %%
model.score(X_val, y_val)
# Out:
# 0.6401995602908845

# %%
y_pred=model.predict(X_val)

# %%
f1 = f1_score(y_val, y_pred)
print(f"F1 score: {f1}")
# Out:
# F1 score: 0.6461538461538462

# %%
test_df=pd.read_csv('Test.csv')
test_df
# Out:
#        Index    V1     V2    V3  V4      V5     V6    V7  V8     V9  ...  \
# 0      40977   3.0   97.0   2.0   3   475.0   23.0  11.0  10  146.0  ...
# 1      24157   7.0   29.0  11.0  10     8.0    2.0  11.0  16   19.0  ...
# 2      56238   2.0    9.0   5.0   1  1003.0   29.0   2.0  29   54.0  ...
# 3      55411   0.0    0.0  22.0  17  1527.0   28.0   4.0  24   28.0  ...
# 4      53175  13.0   -1.0  46.0   6     4.0    5.0  16.0  15   22.0  ...
# ...      ...   ...    ...   ...  ..     ...    ...   ...  ..    ...  ...
# 17471  17197   5.0    8.0   2.0  17  1025.0  114.0   5.0  17   49.0  ...
# 17472  14094   1.0   22.0   4.0  10     1.0    7.0   7.0  10   50.0  ...
# 17473  34598   2.0   66.0   4.0   6  1025.0   38.0   2.0  38   38.0  ...
# 17474  17845   1.0  944.0   6.0   6  1084.0    6.0  14.0  23   68.0  ...
# 17475  11574   2.0  100.0   9.0   1     1.0    0.0   2.0   1    1.0  ...
#
#           V43  V45  V47   V50  V51  V52   V59  V63  V72  V75
# ...

# %%
test_df.columns
# Out:
# Index(['Index', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V13', 'V19', 'V22', 'V30', 'V33', 'V35', 'V36', 'V40', 'V41',
#        'V42', 'V43', 'V45', 'V47', 'V50', 'V51', 'V52', 'V59', 'V63', 'V72',
#        'V75'],
#       dtype='object')

# %%
test_df.shape
# Out:
# (17476, 32)

# %%
test_df.to_csv('Test.csv', index=False)

# %%
Index=test_df['Index']
test_df.drop(['Index'],axis=1,inplace=True)

# %%
y_test=model.predict(test_df)
# Out:
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
y_test
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
result = pd.DataFrame({
    'Index': Index,
    'class': y_test
})

# %%
result
# Out:
#        Index  class
# 0      40977      1
# 1      24157      0
# 2      56238      1
# 3      55411      1
# 4      53175      1
# ...      ...    ...
# 17471  17197      1
# 17472  14094      0
# 17473  34598      1
# 17474  17845      1
# 17475  11574      0
#
# [17476 rows x 2 columns]

# %%
result.to_csv("submission.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result.to_csv("submission.csv", index=False)
#
# NameError: name 'result' is not defined
